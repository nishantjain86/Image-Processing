# %% [markdown]
# 1. Introduction to Python for Image Processing and use of OpenCV, Numpy, and Panda
# 2. Acquisition of Images
# 3. Displaying an image
# 4. Saving an Image
# 5. Image Sampling & Spatial Resolution of Images
# 6. Color image or RGB image, GrayScale Image, and Binary Image
# 7. Quantization & Intensity Resolution of Images
# 8. Image Creation
# 9. Reading an Image and Video from a WebCam
# 10. Saving a Video to the HardDisc

# %%
# Importing Packages
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import sys
from google.colab.patches import cv2_imshow

# %%
a=2
print(a)
# Out:
# 2

# %% [markdown]
# To check the version of the packages and if the packages are installed

# %%
print(cv.__version__)
print(np.__version__)
# Out:
# 4.1.2
# 1.21.5

# %% [markdown]
# **2. Acquisition of Images**
#
# **3. Displaying an image**

# %%
# Reading Image. By default, 2nd argument is cv.IMREAD_COLOR
img1=cv.imread('/content/drive/MyDrive/JUIT/Presentations/DIP using Python/images/a1.png')
# Check if the image is read sucessfully
if img1 is None:
  print("Could not read the image.")
else:
  print("Success")
  cv2_imshow(img1)

# To display images using cv2_imshow package of GoogleColab. It willwork only in Google Colab


# It will not work in google colab as cv2.imshow crashes jupyter
# cv.imshow("Image1",img1)
# k=cv.waitKey(0)
# # if(k==ord("s")):
# cv.destroyWindow("Image1")
# Out:
# Success
# <PIL.Image.Image image mode=RGB size=404x372 at 0x7F3C97D2DE10>

# %%
plt.imshow(img1)

# %%
#TRansforming the color from BGR to RGB fomat
img2 = cv.cvtColor(img1,cv.COLOR_BGR2RGB)
plt.imshow(img2)
plt.figure()
plt.imshow(img1)

# %%
plt.subplot(2,2,1),plt.imshow(img1)
plt.title('Original in BGR fornat')
# plt.xticks([]),plt.yticks([])

plt.subplot(2,2,4),plt.imshow(img2)
plt.title('Original in RGB fornat')
plt.xticks([]),plt.yticks([])
# Out:
# ([], <a list of 0 Text major ticklabel objects>)

# %% [markdown]
# **4. Saving an Image**

# %%
cv.imwrite('/content/drive/MyDrive/JUIT/Presentations/DIP using Python/images/mod.jpg',img1)
# Out:
# True

# %% [markdown]
# **5. Image Sampling & Spatial Resolution of Images**

# %%
print(img1.shape)
# Out:
# (372, 404, 3)

# %%
if (img1.shape[2] == 3):
  print("Image is colorful")
else:
  print("Image is grayscale")
# Out:
# Image is colorful

# %%
img3 = cv.resize(img1,(100,100))
print(img3.shape)
cv.imwrite('/content/drive/MyDrive/JUIT/Presentations/DIP using Python/images/medium.jpg',img3)
# Out:
# (100, 100, 3)
# True

# %%
img4 = cv.resize(img1,(50,50))
print(img4.shape)
cv.imwrite('/content/drive/MyDrive/JUIT/Presentations/DIP using Python/images/low.jpg',img4)
# Out:
# (50, 50, 3)
# True

# %% [markdown]
# **6. Color image or RGB image, GrayScale Image, and Binary Image**

# %%
img5=cv.cvtColor(img1,cv.COLOR_BGR2GRAY)
plt.imshow(img5,cmap='gray')

# %%
img5.shape
# Out:
# (372, 404)

# %%
img1.shape
# Out:
# (372, 404, 3)

# %%
## *Creating Binary Image*
# First argument: source or grayscale image
# Second argument: Threshold value
# Third argument: Maximum value which is assigned to pixel values exceeding the threshold. 
# FOurth argument: Thresholding function

ret,thresh1 = cv.threshold(img5,50,255,cv.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

ret,thresh2 = cv.threshold(img5,100,255,cv.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

ret,thresh3 = cv.threshold(img5,150,255,cv.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

ret,thresh4 = cv.threshold(img5,200,255,cv.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

plt.subplot(2,3,1),plt.imshow(img1, cmap='gray')
plt.title('Original Image')
plt.xticks([]),plt.yticks([])

plt.subplot(2,3,2),plt.imshow(img5, cmap='gray')
plt.title('GrayScale Image')
plt.xticks([]),plt.yticks([])

plt.subplot(2,3,3),plt.imshow(thresh1, cmap='gray')
plt.title('Threshold:50')
plt.xticks([]),plt.yticks([])

plt.subplot(2,3,4),plt.imshow(thresh2, cmap='gray')
plt.title('Threshold:100')
plt.xticks([]),plt.yticks([])

plt.subplot(2,3,5),plt.imshow(thresh3, cmap='gray')
plt.title('Threshold:150')
plt.xticks([]),plt.yticks([])

plt.subplot(2,3,6),plt.imshow(thresh4, cmap='gray')
plt.title('Threshold:200')
plt.xticks([]),plt.yticks([])
# Out:
# (([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %%
f,axs=plt.subplots(3,2,figsize=(18,18), sharex='col', sharey='row', gridspec_kw={'hspace': 0, 'wspace': 1}) #ROW,COLUMN
# axs[0][0].set_yticks([])
axs[0][0].imshow(img1,cmap='gray')
axs[0][1].imshow(img5,cmap='gray')
axs[1][0].imshow(thresh1,cmap='gray')
axs[1][1].imshow(thresh2,cmap='gray')
axs[2][0].imshow(thresh3,cmap='gray')
# axs[2][0].set_yticks([])
axs[2][1].imshow(thresh4,cmap='gray')
axs[0][0].set_title('Original', color='Orange')
axs[0][1].set_title('GrayScale', color='green')
axs[1][0].set_title('Threshold:50', color='green')
axs[1][1].set_title('Threshold:100', color='green')
axs[2][0].set_title('Threshold:150', color='green')
axs[2][1].set_title('Threshold:200', color='green')
# Out:
# Text(0.5, 1.0, 'Threshold:200')

# %% [markdown]
# **7. Quantization & Intensity Resolution of Images**

# %% [markdown]
# **8 Image Creation**

# %%
type(img1)
# Out:
# numpy.ndarray

# %%
a=np.ones((2,3))
print(a.dtype)

b=np.ones((2,3),  np.uint16)
print(b*255)
# Out:
# float64
# [[255 255 255]
#  [255 255 255]]

# %%
ic1 = np.ones((10,10,3),  np.uint8)*255
ic2 = np.concatenate((ic1, 255-ic1), axis=1)
ic3 = np.concatenate((ic2, 255-ic2), axis=0)
# ic2 = cv.cvtColor(ic2,cv.COLOR_BGR2GRAY)
plt.imshow(ic3, cmap='gray')

# %%
ic1 = np.ones((10,10,3),  np.uint8)*255
ic4=ic1
for i in range(0,7):
  ic1 = 255 - ic1
  ic4 = np.concatenate((ic4, ic1), axis=1)
ic1=ic4
for i in range(0,7):
  ic1 = 255 - ic1
  ic4 = np.concatenate((ic4, ic1), axis=0)
plt.imshow(ic4, cmap='gray')

# %%
ic1 = np.ones((10,10,3),  np.uint8)*[255, 120, 0]
ic4=ic1
for i in range(0,7):
  ic1 = 255 - ic1
  ic4 = np.concatenate((ic4, ic1), axis=1)
ic1=ic4
for i in range(0,7):
  ic1 = 255 - ic1
  ic4 = np.concatenate((ic4, ic1), axis=0)
plt.imshow(ic4, cmap='gray')

# %%
np.random.randint(255)
# Out:
# 105

# %%
ic1 = np.ones((100,100,3),  np.uint8)*[np.random.randint(255), np.random.randint(255), np.random.randint(255)]
ic4=ic1
for i in range(0,7):
  ic1 = 255 - ic1
  ic4 = np.concatenate((ic4, ic1), axis=1)
ic1=ic4
for i in range(0,7):
  ic1 = 255 - ic1
  ic4 = np.concatenate((ic4, ic1), axis=0)
plt.imshow(ic4, cmap='gray')

# %%
ic5 =np.array([])
for j in range(0,8):
  ic4 = np.ones((10,10,3),  np.uint8)*[np.random.randint(255), np.random.randint(255), np.random.randint(255)]
  for i in range(0,7):
    ic1 = np.ones((10,10,3),  np.uint8)*[np.random.randint(255), np.random.randint(255), np.random.randint(255)]
    ic4 = np.concatenate((ic4, ic1), axis=1)
    # print(i)
  if ic5.shape[0] ==0:
      ic5=ic4
      # print(j)
  else:
      ic5 = np.vstack((ic4, ic5))
      # print(j)
plt.imshow(ic5, cmap='gray')

# %% [markdown]
# **9. Reading an Image and Video from a WebCam**

# %%
import numpy as np
import cv2 as cv
cap = cv.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()
while True:
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame")
        break
    # Our operations on the frame come here
    # Display the resulting frame
    cv.imshow('frame', frame)
    if cv.waitKey(1) == ord('q'):
        break
cap.release()
cv.destroyAllWindows()
# Out:
# Cannot open camera
# Can't receive frame

# %% [markdown]
# **10. Saving a Video to the HardDisc**

# %%
import numpy as np
import cv2 as cv
cap = cv.VideoCapture(0)
# Define the codec and create VideoWriter object
fourcc = cv.VideoWriter_fourcc(*'XVID')
out = cv.VideoWriter('vid.avi', fourcc, 25.0, (640,  480))
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame")
        break
    out.write(frame)
    cv.imshow('frame', frame)
    if cv.waitKey(1) == ord('q'):
        break
# Release everything if job is finished
cap.release()
out.release()
cv.destroyAllWindows()
