# %% [markdown]
# 1. Histogram
#
# 2. Histogram Equalization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
print(cv2.__version__)
# Out:
# 4.1.2

# %%
im=img.astype('uint32')

# %%
img=cv2.imread(r'/content/drive/MyDrive/JUIT_Courses/DIP using Python/ball3.jpg')
if img is None:
    print("Could not read the image")
else:
    print("Success")
im=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img)
# Out:
# Success

# %%
plt.imshow(im,cmap='gray')

# %%
# plt.imshow(im<100)
hist = cv2.calcHist([im],[0],None,[256],[0,256])
# print(hist)
plt.plot(hist,color = 'red')
plt.xlim([0,256])
# Out:
# (0.0, 256.0)

# %%
img=cv2.imread(r'/content/drive/MyDrive/JUIT_Courses/DIP using Python/ball4.jpg')
if img is None:
    print("Could not read the image")
else:
    print("Success")
im=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img)
# Out:
# Success

# %%
hist = cv2.calcHist([im],[0],None,[256],[0,256])
# print(hist)
plt.plot(hist,color = 'red')
plt.xlim([0,256])
# Out:
# (0.0, 256.0)

# %%
img=cv2.imread(r'/content/drive/MyDrive/JUIT_Courses/DIP using Python/dark.jpg')
if img is None:
    print("Could not read the image")
else:
    print("Success")
im=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(im,cmap='gray')
# Out:
# Success

# %%
hist = cv2.calcHist([im],[0],None,[256],[0,256])
# print(hist)
plt.plot(hist,color = 'red')
plt.xlim([0,256])
# Out:
# (0.0, 256.0)

# %%
im1=im+100
plt.imshow(im1,cmap='gray')

# %%
hist = cv2.calcHist([im1],[0],None,[256],[0,256])
# print(hist)
plt.plot(hist,color = 'red')
plt.xlim([0,256])
# Out:
# (0.0, 256.0)

# %%
equ = cv2.equalizeHist(im)
hist = cv2.calcHist([equ],[0],None,[256],[0,256])
# print(hist)
plt.plot(hist,color = 'red')
plt.xlim([0,256])
# Out:
# (0.0, 256.0)

# %%
plt.imshow(im,cmap='gray')

# %%
plt.imshow(equ,cmap='gray')

# %%
img=cv2.imread(r'/content/drive/MyDrive/JUIT_Courses/DIP using Python/ball4.jpg')
if img is None:
    print("Could not read the image")
else:
    print("Success")
im=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img)
# Out:
# Success

# %%
plt.imshow(im,cmap='gray')

# %%
hist = cv2.calcHist([im],[0],None,[256],[0,256])
# print(hist)
plt.plot(hist,color = 'red')
plt.xlim([0,256])
# Out:
# (0.0, 256.0)

# %%
plt.imshow(((im>120)&(im<150)),cmap='gray')

# %%
plt.imshow(((im>0)&(im<50)),cmap='gray')
